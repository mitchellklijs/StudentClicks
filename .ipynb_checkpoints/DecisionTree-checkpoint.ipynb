# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import seaborn as sns

# The normal imports
from numpy.random import randn

# Import the stats librayr from numpy
from scipy import stats
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB #SciKitLearn GaussianNB Naive Bayes import
from sklearn import tree ##SciKitLearn GaussianNB Naive Bayes import


# Command so that plots appear in the iPython Notebook
# %matplotlib inline

train = pd.read_csv('SumStudentClicksxResult-2-0-50.csv')   # better be in the correct directory!
test = pd.read_csv('SumStudentClicksxResult-2-50-100.csv')
test.head(5)
# Out:
#    id_student  SumOfsum_click final_result
# 0      100893             250         Pass
# 1      101781             891         Pass
# 2      102806             486         Pass
# 3      102952             242         Pass
# 4     1035023             496         Pass

# %%
train.head(5)
# Out:
#    id_student  SumOfsum_click final_result
# 0      100893             206         Pass
# 1      101781            1505         Pass
# 2      102806             590         Pass
# 3      102952             444         Pass
# 4     1035023             459         Pass

# %%
cols = ['SumOfsum_click']
cols2 = ['final_result']

trainArr = train[cols].to_numpy()
trainRes = train[cols2].to_numpy()

testArr = test[cols].to_numpy()
testRes = test[cols2].to_numpy()

#depreciated transformation to numpy array
# trainArr = train.to_numpy(cols)
# trainRes = train.to_numpy(cols2)

# testArr = test.to_numpy(cols)
# testRes = test.to_numpy(cols2)

#clf = GaussianNB()
clf = tree.DecisionTreeClassifier()

# print(trainArr[0])
# print(trainRes[0])
# print(testArr[0])
# print(testRes[0])

output = clf.fit(trainArr, trainRes).predict(testArr)

for i in range(390):
    #if testRes[i][0] == output[i] and testRes[i]=="Distinction":
    #if testRes[i][0] == output[i] and testRes[i]<>"Pass":
    if testRes[i][0] == output[i]:
        print('CORRECT   ' + str(output[i]) + "   " + str(testRes[i]))
        #print("PREDICTION:  " + str(output[i]) + "  " + str(testArr[i]) + "  " + str(testRes[i]) + "     RIGHT")
    else:
        print('INCORRECT ' + str(output[i]) + "   " + str(testRes[i]))
        #print("PREDICTION:  " + str(output[i]) + "  " + str(testArr[i]) + "  " + str(testRes[i]) + "     WRONG")
# Out:
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Withdrawn   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Withdrawn   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Withdrawn   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# INCORRECT Distinction   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# INCORRECT Fail   ['Pass']
# INCORRECT Pass   ['Distinction']
# INCORRECT Fail   ['Pass']
# INCORRECT Fail   ['Withdrawn']
# INCORRECT Fail   ['Pass']
# INCORRECT Fail   ['Withdrawn']
# INCORRECT Distinction   ['Pass']
# CORRECT   Fail   ['Fail']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# INCORRECT Pass   ['Fail']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# CORRECT   Fail   ['Fail']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Fail']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Fail']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# INCORRECT Withdrawn   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# CORRECT   Fail   ['Fail']
# INCORRECT Pass   ['Distinction']
# INCORRECT Distinction   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Distinction   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Withdrawn   ['Pass']
# INCORRECT Withdrawn   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# INCORRECT Distinction   ['Pass']
# INCORRECT Pass   ['Fail']
# INCORRECT Distinction   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Fail']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Distinction']
# INCORRECT Withdrawn   ['Pass']
# CORRECT   Withdrawn   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# INCORRECT Distinction   ['Pass']
# INCORRECT Distinction   ['Withdrawn']
# INCORRECT Fail   ['Pass']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# INCORRECT Withdrawn   ['Pass']
# INCORRECT Pass   ['Fail']
# INCORRECT Pass   ['Fail']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Fail   ['Fail']
# INCORRECT Fail   ['Withdrawn']
# INCORRECT Fail   ['Pass']
# INCORRECT Fail   ['Pass']
# INCORRECT Pass   ['Fail']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Distinction']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# INCORRECT Pass   ['Fail']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Distinction']
# INCORRECT Pass   ['Fail']
# INCORRECT Fail   ['Pass']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Withdrawn   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# INCORRECT Fail   ['Distinction']
# CORRECT   Fail   ['Fail']
# INCORRECT Withdrawn   ['Fail']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# INCORRECT Pass   ['Fail']
# INCORRECT Fail   ['Pass']
# INCORRECT Fail   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# INCORRECT Pass   ['Fail']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Distinction   ['Distinction']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Fail']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Fail']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Fail   ['Fail']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Distinction   ['Pass']
# INCORRECT Withdrawn   ['Fail']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Fail']
# INCORRECT Pass   ['Fail']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# INCORRECT Withdrawn   ['Pass']
# INCORRECT Withdrawn   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Withdrawn   ['Pass']
# INCORRECT Withdrawn   ['Pass']
# INCORRECT Pass   ['Distinction']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Withdrawn']
# INCORRECT Distinction   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Distinction   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Withdrawn   ['Pass']
# INCORRECT Withdrawn   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Fail']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Withdrawn   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Withdrawn   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# INCORRECT Withdrawn   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Withdrawn   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Distinction   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# INCORRECT Pass   ['Distinction']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# CORRECT   Fail   ['Fail']
# INCORRECT Fail   ['Pass']
# CORRECT   Fail   ['Fail']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Fail']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Fail']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Distinction']
# INCORRECT Pass   ['Distinction']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# INCORRECT Fail   ['Distinction']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Fail']
# INCORRECT Pass   ['Fail']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# INCORRECT Pass   ['Distinction']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Fail']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Distinction']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Fail']
# INCORRECT Pass   ['Fail']
# CORRECT   Pass   ['Pass']
# INCORRECT Withdrawn   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Distinction']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Distinction   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Distinction']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# INCORRECT Pass   ['Fail']
# INCORRECT Fail   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# INCORRECT Pass   ['Fail']
# INCORRECT Fail   ['Pass']
# INCORRECT Fail   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Fail']
# INCORRECT Withdrawn   ['Pass']
# INCORRECT Pass   ['Distinction']
# CORRECT   Pass   ['Pass']
# CORRECT   Fail   ['Fail']
# CORRECT   Pass   ['Pass']
# CORRECT   Fail   ['Fail']
# INCORRECT Pass   ['Fail']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# CORRECT   Fail   ['Fail']
# CORRECT   Pass   ['Pass']
# CORRECT   Distinction   ['Distinction']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Fail   ['Fail']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Fail   ['Fail']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Fail']
# INCORRECT Pass   ['Withdrawn']
# INCORRECT Pass   ['Fail']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# INCORRECT Fail   ['Pass']
# INCORRECT Fail   ['Withdrawn']
# INCORRECT Pass   ['Distinction']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Distinction   ['Pass']
# INCORRECT Fail   ['Pass']
# INCORRECT Withdrawn   ['Fail']
# INCORRECT Fail   ['Withdrawn']
# INCORRECT Fail   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Fail']
# CORRECT   Pass   ['Pass']
# INCORRECT Distinction   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Fail   ['Fail']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Fail   ['Fail']
# INCORRECT Fail   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Distinction']
# CORRECT   Pass   ['Pass']
# CORRECT   Fail   ['Fail']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Withdrawn   ['Distinction']
# INCORRECT Withdrawn   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# CORRECT   Pass   ['Pass']
# INCORRECT Pass   ['Withdrawn']
# CORRECT   Pass   ['Pass']
# INCORRECT Distinction   ['Pass']

# %%
#clf = GaussianNB()
clf = tree.DecisionTreeClassifier()

#print(trainArr[0])
#print(trainRes[0])
#print(testArr[0])
#print(testRes[0])

output = clf.fit(trainArr, trainRes).predict(testArr)

for i in range(390):
    #if testRes[i][0] == output[i] and testRes[i]=="Distinction":
    #if testRes[i][0] == output[i] and testRes[i]<>"Pass":
    if testRes[i][0] == output[i]:
        #print ""
        print("PREDICTION:    " + str(output[i]) + "  " + str(testArr[i]) + "       " + str(testRes[i]) + "     CORRECT")
    else:
        print("PREDICTION:    " + str(output[i]) + "  " + str(testArr[i]) + "       " + str(testRes[i]))
# Out:
# PREDICTION:    Fail  [250]       ['Pass']
# PREDICTION:    Pass  [891]       ['Pass']     CORRECT
# PREDICTION:    Pass  [486]       ['Pass']     CORRECT
# PREDICTION:    Pass  [242]       ['Pass']     CORRECT
# PREDICTION:    Pass  [496]       ['Pass']     CORRECT
# PREDICTION:    Pass  [683]       ['Pass']     CORRECT
# PREDICTION:    Withdrawn  [170]       ['Withdrawn']     CORRECT
# PREDICTION:    Pass  [82]       ['Pass']     CORRECT
# PREDICTION:    Fail  [214]       ['Pass']
# PREDICTION:    Pass  [473]       ['Pass']     CORRECT
# PREDICTION:    Pass  [821]       ['Pass']     CORRECT
# PREDICTION:    Pass  [971]       ['Pass']     CORRECT
# PREDICTION:    Pass  [201]       ['Pass']     CORRECT
# PREDICTION:    Withdrawn  [168]       ['Pass']
# PREDICTION:    Pass  [355]       ['Pass']     CORRECT
# PREDICTION:    Withdrawn  [431]       ['Pass']
# PREDICTION:    Pass  [295]       ['Pass']     CORRECT
# PREDICTION:    Pass  [118]       ['Pass']     CORRECT
# PREDICTION:    Fail  [630]       ['Pass']
# PREDICTION:    Distinction  [377]       ['Pass']
# PREDICTION:    Pass  [1086]       ['Withdrawn']
# PREDICTION:    Fail  [94]       ['Pass']
# PREDICTION:    Pass  [671]       ['Distinction']
# PREDICTION:    Fail  [165]       ['Pass']
# PREDICTION:    Fail  [165]       ['Withdrawn']
# PREDICTION:    Fail  [70]       ['Pass']
# PREDICTION:    Fail  [70]       ['Withdrawn']
# PREDICTION:    Distinction  [1744]       ['Pass']
# PREDICTION:    Fail  [62]       ['Fail']     CORRECT
# PREDICTION:    Fail  [154]       ['Pass']
# PREDICTION:    Pass  [451]       ['Pass']     CORRECT
# PREDICTION:    Pass  [136]       ['Pass']     CORRECT
# PREDICTION:    Pass  [136]       ['Withdrawn']
# PREDICTION:    Pass  [457]       ['Fail']
# PREDICTION:    Pass  [440]       ['Pass']     CORRECT
# PREDICTION:    Pass  [1307]       ['Pass']     CORRECT
# PREDICTION:    Fail  [55]       ['Pass']
# PREDICTION:    Fail  [288]       ['Fail']     CORRECT
# PREDICTION:    Pass  [878]       ['Pass']     CORRECT
# PREDICTION:    Pass  [159]       ['Fail']
# PREDICTION:    Pass  [159]       ['Pass']     CORRECT
# PREDICTION:    Pass  [80]       ['Fail']
# PREDICTION:    Pass  [80]       ['Pass']     CORRECT
# PREDICTION:    Pass  [45]       ['Withdrawn']
# PREDICTION:    Pass  [800]       ['Pass']     CORRECT
# PREDICTION:    Pass  [593]       ['Pass']     CORRECT
# PREDICTION:    Pass  [593]       ['Withdrawn']
# PREDICTION:    Withdrawn  [29]       ['Pass']
# PREDICTION:    Pass  [1104]       ['Pass']     CORRECT
# PREDICTION:    Pass  [382]       ['Pass']     CORRECT
# PREDICTION:    Pass  [859]       ['Pass']     CORRECT
# PREDICTION:    Pass  [241]       ['Pass']     CORRECT
# PREDICTION:    Pass  [241]       ['Withdrawn']
# PREDICTION:    Pass  [398]       ['Pass']     CORRECT
# PREDICTION:    Pass  [1218]       ['Withdrawn']
# PREDICTION:    Pass  [274]       ['Pass']     CORRECT
# PREDICTION:    Fail  [150]       ['Fail']     CORRECT
# PREDICTION:    Pass  [1696]       ['Distinction']
# PREDICTION:    Distinction  [1481]       ['Pass']
# PREDICTION:    Pass  [138]       ['Pass']     CORRECT
# PREDICTION:    Pass  [398]       ['Pass']     CORRECT
# PREDICTION:    Pass  [120]       ['Pass']     CORRECT
# PREDICTION:    Pass  [358]       ['Pass']     CORRECT
# PREDICTION:    Pass  [200]       ['Pass']     CORRECT
# PREDICTION:    Distinction  [554]       ['Pass']
# PREDICTION:    Pass  [733]       ['Pass']     CORRECT
# PREDICTION:    Withdrawn  [1520]       ['Pass']
# PREDICTION:    Withdrawn  [1296]       ['Pass']
# PREDICTION:    Pass  [1239]       ['Withdrawn']
# PREDICTION:    Distinction  [763]       ['Pass']
# PREDICTION:    Pass  [14]       ['Fail']
# PREDICTION:    Distinction  [1616]       ['Pass']
# PREDICTION:    Pass  [314]       ['Pass']     CORRECT
# PREDICTION:    Pass  [125]       ['Pass']     CORRECT
# PREDICTION:    Pass  [412]       ['Pass']     CORRECT
# PREDICTION:    Fail  [48]       ['Withdrawn']
# PREDICTION:    Pass  [383]       ['Pass']     CORRECT
# PREDICTION:    Pass  [183]       ['Pass']     CORRECT
# PREDICTION:    Pass  [385]       ['Pass']     CORRECT
# PREDICTION:    Pass  [1508]       ['Pass']     CORRECT
# PREDICTION:    Pass  [122]       ['Fail']
# PREDICTION:    Pass  [1541]       ['Pass']     CORRECT
# PREDICTION:    Pass  [523]       ['Pass']     CORRECT
# PREDICTION:    Pass  [1829]       ['Distinction']
# PREDICTION:    Withdrawn  [430]       ['Pass']
# PREDICTION:    Withdrawn  [430]       ['Withdrawn']     CORRECT
# PREDICTION:    Pass  [467]       ['Pass']     CORRECT
# PREDICTION:    Pass  [191]       ['Pass']     CORRECT
# PREDICTION:    Pass  [532]       ['Pass']     CORRECT
# PREDICTION:    Pass  [301]       ['Pass']     CORRECT
# PREDICTION:    Pass  [701]       ['Pass']     CORRECT
# PREDICTION:    Pass  [404]       ['Pass']     CORRECT
# PREDICTION:    Pass  [71]       ['Pass']     CORRECT
# PREDICTION:    Pass  [768]       ['Withdrawn']
# PREDICTION:    Distinction  [3754]       ['Pass']
# PREDICTION:    Distinction  [3754]       ['Withdrawn']
# PREDICTION:    Fail  [250]       ['Pass']
# PREDICTION:    Fail  [89]       ['Pass']
# PREDICTION:    Pass  [232]       ['Pass']     CORRECT
# PREDICTION:    Fail  [39]       ['Pass']
# PREDICTION:    Pass  [428]       ['Withdrawn']
# PREDICTION:    Pass  [507]       ['Pass']     CORRECT
# PREDICTION:    Withdrawn  [420]       ['Pass']
# PREDICTION:    Pass  [47]       ['Fail']
# PREDICTION:    Pass  [734]       ['Fail']
# PREDICTION:    Pass  [1396]       ['Withdrawn']
# PREDICTION:    Fail  [287]       ['Fail']     CORRECT
# PREDICTION:    Fail  [287]       ['Withdrawn']
# PREDICTION:    Fail  [305]       ['Pass']
# PREDICTION:    Fail  [100]       ['Pass']
# PREDICTION:    Pass  [479]       ['Fail']
# PREDICTION:    Pass  [160]       ['Pass']     CORRECT
# PREDICTION:    Pass  [1113]       ['Distinction']
# PREDICTION:    Pass  [568]       ['Pass']     CORRECT
# PREDICTION:    Pass  [568]       ['Withdrawn']
# PREDICTION:    Pass  [486]       ['Pass']     CORRECT
# PREDICTION:    Pass  [589]       ['Pass']     CORRECT
# PREDICTION:    Pass  [910]       ['Pass']     CORRECT
# PREDICTION:    Fail  [250]       ['Pass']
# PREDICTION:    Pass  [45]       ['Fail']
# PREDICTION:    Pass  [422]       ['Pass']     CORRECT
# PREDICTION:    Pass  [1106]       ['Pass']     CORRECT
# PREDICTION:    Fail  [307]       ['Pass']
# PREDICTION:    Pass  [446]       ['Pass']     CORRECT
# PREDICTION:    Pass  [311]       ['Pass']     CORRECT
# PREDICTION:    Pass  [585]       ['Pass']     CORRECT
# PREDICTION:    Pass  [873]       ['Withdrawn']
# PREDICTION:    Pass  [473]       ['Pass']     CORRECT
# PREDICTION:    Pass  [594]       ['Distinction']
# PREDICTION:    Pass  [409]       ['Fail']
# PREDICTION:    Fail  [39]       ['Pass']
# PREDICTION:    Fail  [56]       ['Pass']
# PREDICTION:    Pass  [203]       ['Pass']     CORRECT
# PREDICTION:    Pass  [191]       ['Pass']     CORRECT
# PREDICTION:    Pass  [285]       ['Pass']     CORRECT
# PREDICTION:    Withdrawn  [30]       ['Pass']
# PREDICTION:    Pass  [509]       ['Withdrawn']
# PREDICTION:    Pass  [690]       ['Pass']     CORRECT
# PREDICTION:    Fail  [89]       ['Pass']
# PREDICTION:    Fail  [211]       ['Distinction']
# PREDICTION:    Fail  [351]       ['Fail']     CORRECT
# PREDICTION:    Withdrawn  [110]       ['Fail']
# PREDICTION:    Pass  [11]       ['Pass']     CORRECT
# PREDICTION:    Pass  [11]       ['Withdrawn']
# PREDICTION:    Pass  [406]       ['Fail']
# PREDICTION:    Fail  [61]       ['Pass']
# PREDICTION:    Fail  [61]       ['Withdrawn']
# PREDICTION:    Pass  [67]       ['Pass']     CORRECT
# PREDICTION:    Pass  [2127]       ['Pass']     CORRECT
# PREDICTION:    Pass  [523]       ['Pass']     CORRECT
# PREDICTION:    Pass  [565]       ['Pass']     CORRECT
# PREDICTION:    Pass  [162]       ['Pass']     CORRECT
# PREDICTION:    Pass  [382]       ['Pass']     CORRECT
# PREDICTION:    Pass  [329]       ['Withdrawn']
# PREDICTION:    Pass  [63]       ['Pass']     CORRECT
# PREDICTION:    Fail  [107]       ['Pass']
# PREDICTION:    Pass  [79]       ['Fail']
# PREDICTION:    Pass  [217]       ['Withdrawn']
# PREDICTION:    Distinction  [1019]       ['Distinction']     CORRECT
# PREDICTION:    Pass  [753]       ['Pass']     CORRECT
# PREDICTION:    Pass  [496]       ['Pass']     CORRECT
# PREDICTION:    Pass  [401]       ['Fail']
# PREDICTION:    Pass  [37]       ['Pass']     CORRECT
# PREDICTION:    Pass  [136]       ['Fail']
# PREDICTION:    Pass  [136]       ['Withdrawn']
# PREDICTION:    Pass  [610]       ['Pass']     CORRECT
# PREDICTION:    Pass  [126]       ['Pass']     CORRECT
# PREDICTION:    Fail  [33]       ['Fail']     CORRECT
# PREDICTION:    Pass  [616]       ['Pass']     CORRECT
# PREDICTION:    Pass  [942]       ['Pass']     CORRECT
# PREDICTION:    Distinction  [739]       ['Pass']
# PREDICTION:    Withdrawn  [420]       ['Fail']
# PREDICTION:    Pass  [227]       ['Pass']     CORRECT
# PREDICTION:    Pass  [277]       ['Fail']
# PREDICTION:    Pass  [889]       ['Fail']
# PREDICTION:    Pass  [889]       ['Withdrawn']
# PREDICTION:    Pass  [81]       ['Pass']     CORRECT
# PREDICTION:    Withdrawn  [431]       ['Pass']
# PREDICTION:    Withdrawn  [437]       ['Pass']
# PREDICTION:    Pass  [677]       ['Pass']     CORRECT
# PREDICTION:    Fail  [599]       ['Pass']
# PREDICTION:    Pass  [413]       ['Pass']     CORRECT
# PREDICTION:    Fail  [632]       ['Pass']
# PREDICTION:    Pass  [461]       ['Pass']     CORRECT
# PREDICTION:    Pass  [130]       ['Pass']     CORRECT
# PREDICTION:    Pass  [127]       ['Pass']     CORRECT
# PREDICTION:    Withdrawn  [229]       ['Pass']
# PREDICTION:    Withdrawn  [197]       ['Pass']
# PREDICTION:    Pass  [225]       ['Distinction']
# PREDICTION:    Pass  [823]       ['Pass']     CORRECT
# PREDICTION:    Pass  [240]       ['Pass']     CORRECT
# PREDICTION:    Fail  [62]       ['Withdrawn']
# PREDICTION:    Distinction  [1064]       ['Pass']
# PREDICTION:    Pass  [660]       ['Pass']     CORRECT
# PREDICTION:    Distinction  [1994]       ['Pass']
# PREDICTION:    Pass  [131]       ['Pass']     CORRECT
# PREDICTION:    Withdrawn  [269]       ['Pass']
# PREDICTION:    Withdrawn  [283]       ['Pass']
# PREDICTION:    Pass  [317]       ['Pass']     CORRECT
# PREDICTION:    Pass  [1]       ['Pass']     CORRECT
# PREDICTION:    Pass  [1]       ['Withdrawn']
# PREDICTION:    Pass  [344]       ['Pass']     CORRECT
# PREDICTION:    Pass  [642]       ['Pass']     CORRECT
# PREDICTION:    Pass  [1]       ['Fail']
# PREDICTION:    Pass  [1]       ['Withdrawn']
# PREDICTION:    Pass  [409]       ['Pass']     CORRECT
# PREDICTION:    Fail  [215]       ['Pass']
# PREDICTION:    Pass  [772]       ['Pass']     CORRECT
# PREDICTION:    Pass  [1400]       ['Pass']     CORRECT
# PREDICTION:    Withdrawn  [269]       ['Pass']
# PREDICTION:    Pass  [405]       ['Pass']     CORRECT
# PREDICTION:    Pass  [193]       ['Pass']     CORRECT
# PREDICTION:    Withdrawn  [173]       ['Pass']
# PREDICTION:    Pass  [280]       ['Withdrawn']
# PREDICTION:    Withdrawn  [68]       ['Pass']
# PREDICTION:    Pass  [422]       ['Pass']     CORRECT
# PREDICTION:    Withdrawn  [198]       ['Pass']
# PREDICTION:    Pass  [246]       ['Pass']     CORRECT
# PREDICTION:    Pass  [718]       ['Pass']     CORRECT
# PREDICTION:    Pass  [158]       ['Pass']     CORRECT
# PREDICTION:    Pass  [603]       ['Pass']     CORRECT
# PREDICTION:    Distinction  [552]       ['Pass']
# PREDICTION:    Pass  [1178]       ['Pass']     CORRECT
# PREDICTION:    Pass  [371]       ['Pass']     CORRECT
# PREDICTION:    Fail  [350]       ['Pass']
# PREDICTION:    Pass  [1701]       ['Distinction']
# PREDICTION:    Fail  [143]       ['Pass']
# PREDICTION:    Pass  [218]       ['Pass']     CORRECT
# PREDICTION:    Fail  [97]       ['Pass']
# PREDICTION:    Fail  [99]       ['Fail']     CORRECT
# PREDICTION:    Fail  [849]       ['Pass']
# PREDICTION:    Fail  [148]       ['Fail']     CORRECT
# PREDICTION:    Pass  [395]       ['Pass']     CORRECT
# PREDICTION:    Pass  [764]       ['Fail']
# PREDICTION:    Pass  [463]       ['Pass']     CORRECT
# PREDICTION:    Pass  [1]       ['Fail']
# PREDICTION:    Pass  [1]       ['Withdrawn']
# PREDICTION:    Pass  [16]       ['Pass']     CORRECT
# PREDICTION:    Pass  [1192]       ['Distinction']
# PREDICTION:    Pass  [661]       ['Distinction']
# PREDICTION:    Fail  [146]       ['Pass']
# PREDICTION:    Pass  [1230]       ['Pass']     CORRECT
# PREDICTION:    Fail  [236]       ['Pass']
# PREDICTION:    Pass  [968]       ['Pass']     CORRECT
# PREDICTION:    Pass  [988]       ['Withdrawn']
# PREDICTION:    Fail  [250]       ['Distinction']
# PREDICTION:    Pass  [119]       ['Pass']     CORRECT
# PREDICTION:    Pass  [16]       ['Fail']
# PREDICTION:    Pass  [5]       ['Fail']
# PREDICTION:    Pass  [503]       ['Pass']     CORRECT
# PREDICTION:    Pass  [271]       ['Pass']     CORRECT
# PREDICTION:    Pass  [450]       ['Pass']     CORRECT
# PREDICTION:    Pass  [158]       ['Pass']     CORRECT
# PREDICTION:    Pass  [481]       ['Pass']     CORRECT
# PREDICTION:    Fail  [115]       ['Pass']
# PREDICTION:    Pass  [1642]       ['Distinction']
# PREDICTION:    Fail  [41]       ['Pass']
# PREDICTION:    Pass  [444]       ['Pass']     CORRECT
# PREDICTION:    Pass  [246]       ['Pass']     CORRECT
# PREDICTION:    Pass  [280]       ['Fail']
# PREDICTION:    Pass  [280]       ['Pass']     CORRECT
# PREDICTION:    Pass  [679]       ['Distinction']
# PREDICTION:    Fail  [96]       ['Pass']
# PREDICTION:    Pass  [312]       ['Pass']     CORRECT
# PREDICTION:    Pass  [341]       ['Fail']
# PREDICTION:    Pass  [12]       ['Fail']
# PREDICTION:    Pass  [204]       ['Pass']     CORRECT
# PREDICTION:    Withdrawn  [270]       ['Pass']
# PREDICTION:    Pass  [324]       ['Pass']     CORRECT
# PREDICTION:    Pass  [880]       ['Pass']     CORRECT
# PREDICTION:    Fail  [286]       ['Pass']
# PREDICTION:    Pass  [464]       ['Pass']     CORRECT
# PREDICTION:    Pass  [838]       ['Pass']     CORRECT
# PREDICTION:    Pass  [3478]       ['Distinction']
# PREDICTION:    Fail  [88]       ['Pass']
# PREDICTION:    Pass  [663]       ['Pass']     CORRECT
# PREDICTION:    Pass  [440]       ['Pass']     CORRECT
# PREDICTION:    Pass  [1250]       ['Pass']     CORRECT
# PREDICTION:    Pass  [3076]       ['Pass']     CORRECT
# PREDICTION:    Pass  [506]       ['Pass']     CORRECT
# PREDICTION:    Distinction  [554]       ['Pass']
# PREDICTION:    Pass  [25]       ['Pass']     CORRECT
# PREDICTION:    Pass  [162]       ['Pass']     CORRECT
# PREDICTION:    Pass  [620]       ['Distinction']
# PREDICTION:    Pass  [620]       ['Withdrawn']
# PREDICTION:    Pass  [396]       ['Pass']     CORRECT
# PREDICTION:    Pass  [46]       ['Pass']     CORRECT
# PREDICTION:    Fail  [95]       ['Pass']
# PREDICTION:    Pass  [21]       ['Fail']
# PREDICTION:    Fail  [51]       ['Withdrawn']
# PREDICTION:    Pass  [885]       ['Pass']     CORRECT
# PREDICTION:    Pass  [885]       ['Withdrawn']
# PREDICTION:    Pass  [365]       ['Pass']     CORRECT
# PREDICTION:    Fail  [101]       ['Pass']
# PREDICTION:    Pass  [66]       ['Fail']
# PREDICTION:    Fail  [101]       ['Pass']
# PREDICTION:    Fail  [101]       ['Withdrawn']
# PREDICTION:    Pass  [513]       ['Pass']     CORRECT
# PREDICTION:    Pass  [206]       ['Pass']     CORRECT
# PREDICTION:    Pass  [1531]       ['Pass']     CORRECT
# PREDICTION:    Pass  [10]       ['Fail']
# PREDICTION:    Withdrawn  [228]       ['Pass']
# PREDICTION:    Pass  [670]       ['Distinction']
# PREDICTION:    Pass  [162]       ['Pass']     CORRECT
# PREDICTION:    Fail  [58]       ['Fail']     CORRECT
# PREDICTION:    Pass  [191]       ['Pass']     CORRECT
# PREDICTION:    Fail  [100]       ['Fail']     CORRECT
# PREDICTION:    Pass  [258]       ['Fail']
# PREDICTION:    Pass  [202]       ['Pass']     CORRECT
# PREDICTION:    Pass  [624]       ['Pass']     CORRECT
# PREDICTION:    Pass  [485]       ['Pass']     CORRECT
# PREDICTION:    Fail  [143]       ['Pass']
# PREDICTION:    Fail  [41]       ['Fail']     CORRECT
# PREDICTION:    Pass  [203]       ['Pass']     CORRECT
# PREDICTION:    Distinction  [320]       ['Distinction']     CORRECT
# PREDICTION:    Pass  [634]       ['Pass']     CORRECT
# PREDICTION:    Pass  [464]       ['Pass']     CORRECT
# PREDICTION:    Pass  [281]       ['Pass']     CORRECT
# PREDICTION:    Fail  [147]       ['Pass']
# PREDICTION:    Fail  [57]       ['Pass']
# PREDICTION:    Pass  [231]       ['Pass']     CORRECT
# PREDICTION:    Pass  [80]       ['Pass']     CORRECT
# PREDICTION:    Fail  [176]       ['Pass']
# PREDICTION:    Pass  [125]       ['Pass']     CORRECT
# PREDICTION:    Pass  [125]       ['Withdrawn']
# PREDICTION:    Fail  [74]       ['Fail']     CORRECT
# PREDICTION:    Pass  [479]       ['Pass']     CORRECT
# PREDICTION:    Pass  [189]       ['Pass']     CORRECT
# PREDICTION:    Pass  [208]       ['Pass']     CORRECT
# PREDICTION:    Fail  [345]       ['Fail']     CORRECT
# PREDICTION:    Fail  [166]       ['Pass']
# PREDICTION:    Pass  [570]       ['Pass']     CORRECT
# PREDICTION:    Fail  [104]       ['Pass']
# PREDICTION:    Pass  [201]       ['Pass']     CORRECT
# PREDICTION:    Pass  [124]       ['Pass']     CORRECT
# PREDICTION:    Pass  [272]       ['Fail']
# PREDICTION:    Pass  [272]       ['Withdrawn']
# PREDICTION:    Pass  [158]       ['Fail']
# PREDICTION:    Pass  [64]       ['Pass']     CORRECT
# PREDICTION:    Fail  [73]       ['Pass']
# PREDICTION:    Fail  [96]       ['Pass']
# PREDICTION:    Fail  [351]       ['Withdrawn']
# PREDICTION:    Pass  [393]       ['Distinction']
# PREDICTION:    Pass  [161]       ['Pass']     CORRECT
# PREDICTION:    Pass  [325]       ['Pass']     CORRECT
# PREDICTION:    Pass  [138]       ['Withdrawn']
# PREDICTION:    Pass  [442]       ['Pass']     CORRECT
# PREDICTION:    Pass  [359]       ['Pass']     CORRECT
# PREDICTION:    Fail  [249]       ['Pass']
# PREDICTION:    Pass  [216]       ['Pass']     CORRECT
# PREDICTION:    Pass  [194]       ['Pass']     CORRECT
# PREDICTION:    Pass  [597]       ['Pass']     CORRECT
# PREDICTION:    Pass  [1004]       ['Pass']     CORRECT
# PREDICTION:    Distinction  [549]       ['Pass']
# PREDICTION:    Fail  [214]       ['Pass']
# PREDICTION:    Withdrawn  [29]       ['Fail']
# PREDICTION:    Fail  [146]       ['Withdrawn']
# PREDICTION:    Fail  [132]       ['Pass']
# PREDICTION:    Pass  [340]       ['Pass']     CORRECT
# PREDICTION:    Pass  [335]       ['Pass']     CORRECT
# PREDICTION:    Pass  [26]       ['Fail']
# PREDICTION:    Pass  [467]       ['Pass']     CORRECT
# PREDICTION:    Distinction  [1889]       ['Pass']
# PREDICTION:    Pass  [123]       ['Pass']     CORRECT
# PREDICTION:    Pass  [191]       ['Pass']     CORRECT
# PREDICTION:    Pass  [444]       ['Withdrawn']
# PREDICTION:    Fail  [98]       ['Fail']     CORRECT
# PREDICTION:    Pass  [1099]       ['Pass']     CORRECT
# PREDICTION:    Pass  [717]       ['Pass']     CORRECT
# PREDICTION:    Fail  [77]       ['Fail']     CORRECT
# PREDICTION:    Fail  [77]       ['Withdrawn']
# PREDICTION:    Pass  [679]       ['Pass']     CORRECT
# PREDICTION:    Pass  [241]       ['Pass']     CORRECT
# PREDICTION:    Pass  [1353]       ['Distinction']
# PREDICTION:    Pass  [533]       ['Pass']     CORRECT
# PREDICTION:    Fail  [41]       ['Fail']     CORRECT
# PREDICTION:    Pass  [1004]       ['Pass']     CORRECT
# PREDICTION:    Pass  [590]       ['Pass']     CORRECT
# PREDICTION:    Withdrawn  [2401]       ['Distinction']
# PREDICTION:    Withdrawn  [170]       ['Pass']
# PREDICTION:    Pass  [837]       ['Pass']     CORRECT
# PREDICTION:    Pass  [440]       ['Pass']     CORRECT
# PREDICTION:    Pass  [45]       ['Pass']     CORRECT
# PREDICTION:    Pass  [45]       ['Withdrawn']
# PREDICTION:    Pass  [455]       ['Pass']     CORRECT
# PREDICTION:    Pass  [388]       ['Pass']     CORRECT
# PREDICTION:    Pass  [262]       ['Pass']     CORRECT
# PREDICTION:    Pass  [816]       ['Withdrawn']
# PREDICTION:    Pass  [606]       ['Pass']     CORRECT
# PREDICTION:    Distinction  [1881]       ['Pass']

# %%
correct = 0.0

for i in range(len(output)): 
    if testRes[i][0] == output[i]: 
        correct += 1
    
print(correct / len(output))


#print("Accuracy: " + gnb.score(testArr, testRes))
print("Accuracy: " + str(clf.score(testArr, testRes)))
# Out:
# 0.5370843989769821
# Accuracy: 0.5370843989769821

# %%
expected = testRes
predicted = clf.predict(testArr)
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
#               precision    recall  f1-score   support
#
#  Distinction       0.11      0.10      0.10        21
#         Fail       0.21      0.32      0.25        50
#         Pass       0.71      0.69      0.70       275
#    Withdrawn       0.07      0.04      0.05        45
#
#     accuracy                           0.54       391
#    macro avg       0.27      0.29      0.28       391
# weighted avg       0.54      0.54      0.54       391
#
# [[  2   2  16   1]
#  [  0  16  31   3]
#  [ 15  48 190  22]
#  [  1  11  31   2]]

# %%
count=0 
passn=0
fail=0
distinction=0
withdrawn=0
for i in range(len(output)): 
    count += 1
    if testRes[i][0]=='Pass':
        passn += 1
    if testRes[i][0]=='Fail':
        fail += 1
    if testRes[i][0]=='Distinction':
        distinction += 1
    if testRes[i][0]=='Withdrawn':
        withdrawn += 1
print ("Pass: " + str(passn))
print ("Fail: " + str(fail))
print ("Distinction: " + str(distinction))
print ("Withdrawn: " + str(withdrawn))
# Out:
# Pass: 275
# Fail: 50
# Distinction: 21
# Withdrawn: 45

# %%
feature_names=('Pass','Fail', 'Distinction', 'Withdrawn')
with open("studentTree.dot", 'w') as f:
         f = tree.export_graphviz(clf, out_file=f, feature_names=feature_names)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-04d931d37048> in <module>
#       1 feature_names=('Pass','Fail', 'Distinction', 'Withdrawn')
#       2 with open("studentTree.dot", 'w') as f:
# ----> 3          f = tree.export_graphviz(clf, out_file=f, feature_names=feature_names)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision)
#     781             rounded=rounded, special_characters=special_characters,
#     782             precision=precision)
# --> 783         exporter.export(decision_tree)
#     784
#     785         if return_string:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_export.py in export(self, decision_tree)
#     411         if self.feature_names is not None:
#     412             if len(self.feature_names) != decision_tree.n_features_:
# --> 413                 raise ValueError("Length of feature_names, %d "
#     414                                  "does not match number of features, %d"
#     415                                  % (len(self.feature_names),
#
# ValueError: Length of feature_names, 4 does not match number of features, 1

# %%
plt.hist(testArr)
# Out:
# (array([216., 109.,  35.,  12.,  10.,   4.,   1.,   0.,   1.,   3.]),
#  array([1.0000e+00, 3.7630e+02, 7.5160e+02, 1.1269e+03, 1.5022e+03,
#         1.8775e+03, 2.2528e+03, 2.6281e+03, 3.0034e+03, 3.3787e+03,
#         3.7540e+03]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(testArr, normed=True,color='indianred',alpha=0.5,bins=20)
#plt.hist(output, normed=True,alpha=0.5,bins=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-5f7e62959a5f> in <module>
# ----> 1 plt.hist(testArr, normed=True,color='indianred',alpha=0.5,bins=20)
#       2 #plt.hist(output, normed=True,alpha=0.5,bins=20)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2603         orientation='vertical', rwidth=None, log=False, color=None,
#    2604         label=None, stacked=False, *, data=None, **kwargs):
# -> 2605     return gca().hist(
#    2606         x, bins=bins, range=range, density=density, weights=weights,
#    2607         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6817             if patch:
#    6818                 p = patch[0]
# -> 6819                 p.update(kwargs)
#    6820                 if lbl is not None:
#    6821                     p.set_label(lbl)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#     999                 func = getattr(self, 'set_' + k, None)
#    1000                 if not callable(func):
# -> 1001                     raise AttributeError('{!r} object has no property {!r}'
#    1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
sns.distplot(testArr,bins=25,
            kde_kws={'color':'indianred','label':'KDE PLOT'},
            hist_kws={'color':'blue','label':"HIST"})

# %%
plt.hist(testArr, normed=True,color='indianred',alpha=0.5,bins=20)
plt.hist(trainArr, normed=True,alpha=0.5,bins=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-ef1d02407d01> in <module>
# ----> 1 plt.hist(testArr, normed=True,color='indianred',alpha=0.5,bins=20)
#       2 plt.hist(trainArr, normed=True,alpha=0.5,bins=20)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2603         orientation='vertical', rwidth=None, log=False, color=None,
#    2604         label=None, stacked=False, *, data=None, **kwargs):
# -> 2605     return gca().hist(
#    2606         x, bins=bins, range=range, density=density, weights=weights,
#    2607         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6817             if patch:
#    6818                 p = patch[0]
# -> 6819                 p.update(kwargs)
#    6820                 if lbl is not None:
#    6821                     p.set_label(lbl)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#     999                 func = getattr(self, 'set_' + k, None)
#    1000                 if not callable(func):
# -> 1001                     raise AttributeError('{!r} object has no property {!r}'
#    1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
sns.heatmap(testArr)
